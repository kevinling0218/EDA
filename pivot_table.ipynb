# %%
import os 
import pandas as pd
import numpy as np

# %%
DATA_FOLDER = './housing_price/data'
df = pd.read_csv(os.path.join(DATA_FOLDER, 'train.csv'))

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.pivot_table (df,index = ['YrSold','SaleCondition'])
# Out:
#                          1stFlrSF    2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# YrSold SaleCondition
# 2006   Abnorml        1072.969697  245.606061   5.454545      2.848485
#        AdjLand         819.000000  263.000000   0.000000      4.500000
#        Alloca         1575.000000  626.000000   0.000000      4.000000
#        Family         1284.125000  196.500000   0.000000      3.500000
#        Normal         1139.299559  361.533040   1.850220      2.845815
#        Partial        1322.325581  446.976744   4.441860      2.813953
# 2007   Abnorml        1286.230769  604.615385   0.000000      3.384615
#        AdjLand         756.000000  378.000000   0.000000      3.000000
#        Alloca         1862.000000  418.000000   0.000000      3.333333
#        Family         1255.428571  398.285714   0.000000      3.285714
#        Normal         1146.732075  348.581132   1.962264      2.943396
#        Partial        1433.300000  323.725000   0.000000      2.775000
# ...

# %%
# Default aggregation method is mean value 
pd.pivot_table (df,index = ['YrSold','SaleCondition'],values = ['SalePrice'])
# Out:
#                           SalePrice
# YrSold SaleCondition
# 2006   Abnorml        142857.363636
#        AdjLand        104250.000000
#        Alloca         274970.000000
#        Family         138500.000000
#        Normal         175522.612335
#        Partial        259793.813953
# 2007   Abnorml        198346.153846
#        AdjLand        126000.000000
#        Alloca         216398.333333
#        Family         176142.857143
#        Normal         175312.124528
#        Partial        254259.225000
# 2008   Abnorml        154500.000000
#        AdjLand         82000.000000
#        Alloca         157629.500000
#        Normal         172062.556818
#        Partial        303213.812500
# 2009   Abnorml        132692.173913
#        Alloca         142622.400000
#        Family         131000.000000
#        Normal         177025.190972
#        Partial        289829.684211
# 2010   Abnorml        109997.818182
#        Alloca          55993.000000
# ...

# %%
# Using mean and len to get a count 
pd.pivot_table (df,index = ['YrSold','SaleCondition'],values = ['SalePrice'],aggfunc=[np.median,len])
# Out:
#                         median       len
#                      SalePrice SalePrice
# YrSold SaleCondition
# 2006   Abnorml        130000.0        33
#        AdjLand        104250.0         2
#        Alloca         274970.0         1
#        Family         135000.0         8
#        Normal         159500.0       227
#        Partial        232600.0        43
# 2007   Abnorml        150000.0        13
#        AdjLand        126000.0         1
#        Alloca         200624.0         3
#        Family         136000.0         7
#        Normal         156000.0       265
#        Partial        233437.5        40
# 2008   Abnorml        140000.0        21
#        AdjLand         82000.0         1
#        Alloca         157629.5         2
#        Normal         162950.0       264
#        Partial        316413.5        16
# 2009   Abnorml        125000.0        23
#        Alloca         142953.0         5
#        Family         152000.0         3
# ...

# %%
# Further segragating using column 
# fill_value to deal with NaN problem
pd.pivot_table (df,index = ['YrSold','SaleCondition'],
                columns = ['Utilities'],values = ['SalePrice'],
                aggfunc=[np.median,len],fill_value = 0)
# Out:
#                         median               len
#                      SalePrice         SalePrice
# Utilities               AllPub  NoSeWa    AllPub NoSeWa
# YrSold SaleCondition
# 2006   Abnorml        130000.0       0        33      0
#        AdjLand        104250.0       0         2      0
#        Alloca         274970.0       0         1      0
#        Family         135000.0       0         8      0
#        Normal         159500.0       0       227      0
#        Partial        232600.0       0        43      0
# 2007   Abnorml        150000.0       0        13      0
#        AdjLand        126000.0       0         1      0
#        Alloca         200624.0       0         3      0
#        Family         136000.0       0         7      0
#        Normal         156000.0       0       265      0
#        Partial        233437.5       0        40      0
# 2008   Abnorml        140000.0       0        21      0
#        AdjLand         82000.0       0         1      0
# ...

# %%
# The result is still a DataFrame

table = pd.pivot_table (df,index = ['YrSold','SaleCondition'],
                columns = ['Utilities'],values = ['SalePrice'],
                aggfunc=[np.median,len],fill_value = 0)

# %%
# Only look at certain SaleCondition
table.query('SaleCondition == ["Normal","Family"]')
# Out:
#                         median              len
#                      SalePrice        SalePrice
# Utilities               AllPub NoSeWa    AllPub NoSeWa
# YrSold SaleCondition
# 2006   Family         135000.0      0         8      0
#        Normal         159500.0      0       227      0
# 2007   Family         136000.0      0         7      0
#        Normal         156000.0      0       265      0
# 2008   Normal         162950.0      0       264      0
# 2009   Family         152000.0      0         3      0
#        Normal         162750.0      0       288      0
# 2010   Family         129000.0      0         2      0
#        Normal         156450.0      0       154      0
